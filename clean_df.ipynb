# %%
import pandas as pd


df = pd.read_excel('data/Матрица продаж 09042024.xlsx')
clean_df = df[~((df.loc[:, 'Таргет'] == 0))]

clean_df['Продано нежилых, м2'] = clean_df['Продано нежилых, м2'].apply(pd.to_numeric)

missing_cols, missing_rows = (
    (clean_df.isnull().sum(x) | clean_df.eq('').sum(x))
    .loc[lambda x: x.gt(0)].index
    for x in (0, 1)
)

clean_df = clean_df.drop(missing_cols, axis=1)

new_col = clean_df['Проект'].astype(str) + ' ' + clean_df['Корпус'].astype(str)
clean_df = clean_df.drop(['Проект', 'Корпус', 'Продано квартир, шт', 'Продано квартир, м2'], axis=1)
clean_df.insert(0, 'ЖК', new_col)

clean_df
# Out:
# /tmp/ipykernel_342/1017226454.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df['Продано нежилых, м2'] = clean_df['Продано нежилых, м2'].apply(pd.to_numeric)
#                            ЖК index()           Регион Населенный пункт  \
# 40                Тепло 37875      41  Приморский край            Артем
# 41                Тепло 37875      42  Приморский край            Артем
# 42                Тепло 37875      43  Приморский край            Артем
# 43                Тепло 37875      44  Приморский край            Артем
# 44                Тепло 37875      45  Приморский край            Артем
# ...                       ...     ...              ...              ...
# 6379           Корсаков 36964   6 380  Приморский край        Уссурийск
# 6397  Юных пионеров, 35 37495   6 398  Приморский край       Черниговка
# 6399  Юных пионеров, 35 37495   6 400  Приморский край       Черниговка
# 6406  Юных пионеров, 35 37495   6 407  Приморский край       Черниговка
# 6416  Юных пионеров, 35 37495   6 417  Приморский край       Черниговка
#
#        Группа компаний  ID проекта Класс недвижимости    Статус         Месяц  \
# 40              Регион       10578            Комфорт      Сдан   Январь 2021
# 41              Регион       10578            Комфорт      Сдан  Февраль 2021
# 42              Регион       10578            Комфорт      Сдан     Март 2021
# 43              Регион       10578            Комфорт      Сдан   Апрель 2021
# 44              Регион       10578            Комфорт      Сдан      Май 2021
# ...                ...         ...                ...       ...           ...
# 6379  УссурЭкономСтрой      206785            Комфорт      Сдан     Март 2022
# 6397            Ар.Сей       10459            Типовой  Строится   Январь 2021
# 6399            Ар.Сей       10459            Типовой  Строится     Март 2021
# 6406            Ар.Сей       10459            Типовой  Строится  Октябрь 2021
# 6416            Ар.Сей       10459            Типовой  Строится   Август 2022
#
#       Продано квартир, руб  Продано нежилых, шт  Продано нежилых, м2  \
# 40              12698940.0                  0.0                 0.00
# 41              41965085.0                  1.0                 5.42
# 42              33392760.0                  3.0                30.75
# 43              22799930.0                  1.0                 5.22
# 44              20150100.0                  0.0                 0.00
# ...                    ...                  ...                  ...
# 6379            32495100.0                  0.0                 0.00
# 6397             3979300.0                  0.0                 0.00
# 6399            10518950.0                  0.0                 0.00
# 6406             2562300.0                  0.0                 0.00
# 6416             3918400.0                  0.0                 0.00
#
#       Продано нежилых, руб  Продано машиномест, шт  Продано машиномест, м2  \
# 40                     0.0                     0.0                     0.0
# 41                162600.0                     0.0                     0.0
# 42                922500.0                     0.0                     0.0
# 43                156600.0                     0.0                     0.0
# 44                     0.0                     0.0                     0.0
# ...                    ...                     ...                     ...
# 6379                   0.0                     0.0                     0.0
# 6397                   0.0                     0.0                     0.0
# 6399                   0.0                     0.0                     0.0
# 6406                   0.0                     0.0                     0.0
# 6416                   0.0                     0.0                     0.0
#
#             Таргет
# 40     75333.33333
# 41     79341.08183
# 42     81417.95484
# 43     80162.89290
# 44     80170.68513
# ...            ...
# 6379  117154.34260
# 6397   65000.00000
# 6399   66102.87187
# 6406   73000.00000
# 6416   80000.00000
#
# [1673 rows x 16 columns]

# %%
df_houses = pd.read_excel('data/Рабочая_таблица_Данные_о_ЖК_Владивостока_v4_1_с_новым_атрибутом 09042024.xlsx')
df_houses = df_houses.T
df_houses

# df_houses = df_houses.drop(df_houses.iloc[:, 94:], axis=1) это работает
# df_houses = df_houses.drop(df_houses.iloc[:, 92:93], axis=1)
# df_houses

# result_df = clean_df.merge(df_houses, on='ЖК', how='left') это не работает

# и это почему-то не работает
start_col_index = df_houses.columns.get_loc('Общая сумма полученных денег с проданных квартир, руб') 
end_col_index = df_houses.columns.get_loc('Количество проданных нежилых помещений')

df_houses = df_houses.drop(df_houses.columns[start_col_index:end_col_index + 1], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_342/1824481924.py in ?()
#       5 # df_houses = df_houses.drop(df_houses.iloc[:, 94:], axis=1)
#       6 # df_houses = df_houses.drop(df_houses.iloc[:, 92:93], axis=1)
#       7 # df_houses
#       8
# ----> 9 result_df = clean_df.merge(df_houses, on='ЖК', how='left')
#      10
#      11 start_col_index = df_houses.columns.get_loc('Общая сумма полученных денег с проданных квартир, руб')
#      12 end_col_index = df_houses.columns.get_loc('Количество проданных нежилых помещений')
#
# /var/data/python/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10828         validate: MergeValidate | None = None,
#   10829     ) -> DataFrame:
#   10830         from pandas.core.reshape.merge import merge
#   10831
# > 10832         return merge(
#   10833             self,
#   10834             right,
#   10835             how=how,
#
# /var/data/python/lib/python3.11/site-packages/pandas/core/reshape/merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# /var/data/python/lib/python3.11/site-packages/pandas/core/reshape/merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     790             self.right_join_keys,
#     791             self.join_names,
#     792             left_drop,
#     793             right_drop,
# --> 794         ) = self._get_merge_keys()
#     795
#     796         if left_drop:
#     797             self.left = self.left._drop_labels_or_levels(left_drop)
#
# /var/data/python/lib/python3.11/site-packages/pandas/core/reshape/merge.py in ?(self)
#    1293                         # Then we're either Hashable or a wrong-length arraylike,
#    1294                         #  the latter of which will raise
#    1295                         rk = cast(Hashable, rk)
#    1296                         if rk is not None:
# -> 1297                             right_keys.append(right._get_label_or_level_values(rk))
#    1298                         else:
#    1299                             # work-around for merge_asof(right_index=True)
#    1300                             right_keys.append(right.index._values)
#
# /var/data/python/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1907             values = self.xs(key, axis=other_axes[0])._values
#    1908         elif self._is_level_reference(key, axis=axis):
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#    1914         if values.ndim > 1:
#
# KeyError: 'ЖК'
