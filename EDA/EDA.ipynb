# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
from scipy. stats import pearsonr
import numpy as np
import matplotlib.pyplot as plt

# %%
# result = pd.read_excel(r'/home/maxleb/Desktop/FEIP/square_meter/data/result_prepared_df.xlsx', index_col=0)
result = pd.read_excel(r'../data/result_prepared_df.xlsx', index_col=0)
result.head()
# Out:
#              ЖК index()           Регион Населенный пункт Группа компаний  \
# 0  Восход 40376     258  Приморский край            Артем        СЗВОСХОД
# 1  Восход 40376     261  Приморский край            Артем        СЗВОСХОД
# 2  Восход 40376     262  Приморский край            Артем        СЗВОСХОД
# 3  Восход 40376     263  Приморский край            Артем        СЗВОСХОД
# 4  Восход 40376     264  Приморский край            Артем        СЗВОСХОД
#
#    ID проекта  Класс недвижимости  Статус         Месяц  Продано квартир, руб  \
# 0       11228                 0.0       0   Август 2021             4142000.0
# 1       11228                 0.0       0   Ноябрь 2021             7144200.0
# 2       11228                 0.0       0  Декабрь 2021             5968200.0
# 3       11228                 0.0       0   Январь 2022             7800300.0
# 4       11228                 0.0       0  Февраль 2022             5101200.0
#
#    ...  Вспомогательный материал фасада_Стекло  Тип дома_Другой  \
# 0  ...                                       1                0
# 1  ...                                       1                0
# 2  ...                                       1                0
# 3  ...                                       1                0
# 4  ...                                       1                0
#
#    Тип дома_Монолит  Тип дома_Монолитный каркас  Тип дома_Панель  \
# 0                 1                           0                0
# 1                 1                           0                0
# 2                 1                           0                0
# 3                 1                           0                0
# 4                 1                           0                0
#
#    Тип фасада_Другой  Тип фасада_Кирпич  Тип фасада_Навесной фасад  \
# 0                  0                  0                          0
# 1                  0                  0                          0
# 2                  0                  0                          0
# 3                  0                  0                          0
# 4                  0                  0                          0
#
#   Тип фасада_Панель Тип фасада_Стекло
# 0                 1                 0
# 1                 1                 0
# 2                 1                 0
# 3                 1                 0
# 4                 1                 0
#
# [5 rows x 145 columns]

# %%
data = result.drop(result.columns[:6], axis=1)
data = data.drop(['Месяц', 'Таргет', 'Дата получения РС', 'Дата публикации ИНС', 'Дата сбора информации'], axis=1)
attributes = data.columns
attributes
# Out:
# Index(['Класс недвижимости', 'Статус', 'Продано квартир, руб',
#        'Продано нежилых, шт', 'Продано нежилых, м2', 'Продано нежилых, руб',
#        'Продано машиномест, шт', 'Продано машиномест, м2',
#        'Количество квартир', 'Общая площадь квартир',
#        ...
#        'Вспомогательный материал фасада_Стекло', 'Тип дома_Другой',
#        'Тип дома_Монолит', 'Тип дома_Монолитный каркас', 'Тип дома_Панель',
#        'Тип фасада_Другой', 'Тип фасада_Кирпич', 'Тип фасада_Навесной фасад',
#        'Тип фасада_Панель', 'Тип фасада_Стекло'],
#       dtype='object', length=134)

# %%
important = []
unimportant = []
for atr in attributes:
    p_value = []
    target = 'Таргет'

    # plt.figure(figsize=(10, 6))

    # plt.subplot(2, 2, 1)
    # plt.hist(result[atr], bins=10, color='blue', alpha=0.7)
    # plt.xlabel(atr)
    # plt.ylabel('Частота')
    # plt.title('Распределение : ' + atr)

    # plt.subplot(2, 2, 2)
    # plt.scatter(result[target], result[atr], color='green')
    # plt.xlabel(target)
    # plt.ylabel(atr)
    # plt.title('Диаграмма рассеяния')

    # plt.subplot(2, 2, 3)
    # plt.boxplot(result[atr])
    # plt.ylabel('Количество')
    # plt.title('Анализ выбросов : ' + atr)

    # plt.tight_layout()
    # plt.show()

    print(f'Корреляция и p_value: {atr}')
    p_value = pearsonr(result['Таргет'], result[atr])
    print("p_value:", p_value)
    if p_value[1] < 0.05:
        print("Корреляция ЯВЛЯЕТСЯ статистически значимой")
        important.append([atr, p_value[0]])
    else:
        print("Корреляция НЕ является статистически значимой")
        unimportant.append([atr, p_value[0]])
# Out:
# Корреляция и p_value: Класс недвижимости
# p_value: PearsonRResult(statistic=0.4826699344099251, pvalue=5.4387306331337625e-61)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Статус
# p_value: PearsonRResult(statistic=-0.05285235952173934, pvalue=0.09063733013162807)
# Корреляция НЕ является статистически значимой
# Корреляция и p_value: Продано квартир, руб
# p_value: PearsonRResult(statistic=0.01392906929086924, pvalue=0.6558551237889131)
# Корреляция НЕ является статистически значимой
# Корреляция и p_value: Продано нежилых, шт
# p_value: PearsonRResult(statistic=0.04542514745557828, pvalue=0.14594618056225947)
# Корреляция НЕ является статистически значимой
# Корреляция и p_value: Продано нежилых, м2
# p_value: PearsonRResult(statistic=0.07533879696120478, pvalue=0.01579215475869002)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Продано нежилых, руб
# p_value: PearsonRResult(statistic=0.09693358654878026, pvalue=0.0018807776948304446)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Продано машиномест, шт
# p_value: PearsonRResult(statistic=0.11187459375008572, pvalue=0.000330184119719866)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Продано машиномест, м2
# p_value: PearsonRResult(statistic=0.10753711076264945, pvalue=0.0005598449201852492)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Количество квартир
# p_value: PearsonRResult(statistic=0.06239944149333901, pvalue=0.04569040870245267)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Общая площадь квартир
# p_value: PearsonRResult(statistic=0.149419553158055, pvalue=1.5300562048264805e-06)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Подъездов в доме
# p_value: PearsonRResult(statistic=-0.08656126706501877, pvalue=0.005528775341977198)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Количество квартир на этаже
# p_value: PearsonRResult(statistic=-0.05764213087071952, pvalue=0.06494556839684945)
# Корреляция НЕ является статистически значимой
# Корреляция и p_value: Количество этажей
# p_value: PearsonRResult(statistic=0.12813749895558818, pvalue=3.848712932583313e-05)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Пассажирских лифтов в доме
# p_value: PearsonRResult(statistic=0.16949700423555397, pvalue=4.704075355811034e-08)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Грузовых лифтов в доме
# p_value: PearsonRResult(statistic=0.062016441421152785, pvalue=0.047038487720866315)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Инфраструктура: Продукты
# p_value: PearsonRResult(statistic=0.1627086477296721, pvalue=1.6026039978632204e-07)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Инфраструктура: Медицина
# p_value: PearsonRResult(statistic=0.34452985532262287, pvalue=5.748206672841678e-30)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Инфраструктура: Спорт
# p_value: PearsonRResult(statistic=0.2656511821738228, pvalue=4.940573770731325e-18)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Инфраструктура: Новостройки
# p_value: PearsonRResult(statistic=-0.22467311495328138, pvalue=3.311919543219469e-13)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Инфраструктура: Школы
# p_value: PearsonRResult(statistic=0.15804750148244973, pvalue=3.612915856432224e-07)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Инфраструктура: Детские сады
# p_value: PearsonRResult(statistic=0.17117587063680173, pvalue=3.447196828598676e-08)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Всероссийский застройщик
# p_value: PearsonRResult(statistic=0.2810553135269128, pvalue=4.425171685878253e-20)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Количество студий
# p_value: PearsonRResult(statistic=-0.04466247868034856, pvalue=0.15284224889697048)
# Корреляция НЕ является статистически значимой
# Корреляция и p_value: Количество однокомнатных квартир
# p_value: PearsonRResult(statistic=-0.11282225494278313, pvalue=0.0002934691797120025)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Количество двухкомнатных квартир
# p_value: PearsonRResult(statistic=0.09437387066001907, pvalue=0.002478266745872228)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Количество трехкомнатных квартир
# p_value: PearsonRResult(statistic=0.1635486548560884, pvalue=1.380781807891917e-07)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Количество четырехкомнатных квартир
# p_value: PearsonRResult(statistic=0.24223676839505864, pvalue=3.62834845439433e-15)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Количество остальных квартир
# p_value: PearsonRResult(statistic=0.16873910544688286, pvalue=5.4073612963467724e-08)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Высота потолков
# p_value: PearsonRResult(statistic=0.30792515621046423, pvalue=5.663661975097498e-24)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Площадь коммерческих помещений
# p_value: PearsonRResult(statistic=0.12670280051394878, pvalue=4.703079015397292e-05)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Всего парковочных мест
# p_value: PearsonRResult(statistic=0.047485400403915454, pvalue=0.12850610707278626)
# Корреляция НЕ является статистически значимой
# Корреляция и p_value: Парковочных мест внутри дома
# p_value: PearsonRResult(statistic=0.27308813436907164, pvalue=5.265933615055745e-19)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Парковочных мест у дома
# p_value: PearsonRResult(statistic=-0.028646460075476388, pvalue=0.3593255163250369)
# Корреляция НЕ является статистически значимой
# Корреляция и p_value: Гостевых мест
# p_value: PearsonRResult(statistic=-0.19713772802656723, pvalue=1.896781165402304e-10)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Общая площадь земельного участка
# p_value: PearsonRResult(statistic=-0.12783834320683266, pvalue=4.0137112881302876e-05)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Площадь детских площадок
# p_value: PearsonRResult(statistic=0.2055630635874162, pvalue=2.980553257422455e-11)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Площадь особых площадок
# p_value: PearsonRResult(statistic=0.14475628828950363, pvalue=3.2301963270593807e-06)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Площадь спортивных площадок
# p_value: PearsonRResult(statistic=0.06533105353257491, pvalue=0.03640999587233403)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Высота над уровнем моря
# p_value: PearsonRResult(statistic=-0.1514280662931521, pvalue=1.1011697401138714e-06)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Самая низкая точка 250м
# p_value: PearsonRResult(statistic=-0.2302190084596345, pvalue=8.28488412826829e-14)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Самая высокая точка 250м
# p_value: PearsonRResult(statistic=-0.12084768693439193, pvalue=0.00010427988577653008)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Широта
# p_value: PearsonRResult(statistic=-0.2918421820807329, pvalue=1.3581080962489057e-21)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Долгота
# p_value: PearsonRResult(statistic=-0.10070340121583163, pvalue=0.0012381791039824082)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Количество домов 250м
# p_value: PearsonRResult(statistic=0.031630231893641544, pvalue=0.3114550580752642)
# Корреляция НЕ является статистически значимой
# Корреляция и p_value: Средняя этажность 250м
# p_value: PearsonRResult(statistic=-0.06435218917344199, pvalue=0.03931222097699363)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Расстояние до ближайшего строения
# p_value: PearsonRResult(statistic=-0.15158551671969453, pvalue=1.0729443884179544e-06)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Инфраструктура: Торговые центры
# p_value: PearsonRResult(statistic=-0.01902998055396974, pvalue=0.5426133561850447)
# Корреляция НЕ является статистически значимой
# Корреляция и p_value: Инфраструктура: Супермаркеты
# p_value: PearsonRResult(statistic=0.01364007563273089, pvalue=0.6625493165790948)
# Корреляция НЕ является статистически значимой
# Корреляция и p_value: Инфраструктура: Рядом ВУЗ
# p_value: PearsonRResult(statistic=-0.14395010201284697, pvalue=3.6670984190170612e-06)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Есть железная дорога 250м
# p_value: PearsonRResult(statistic=0.35780587142098186, pvalue=2.38921066357271e-32)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Есть ЛЭП 100м
# p_value: PearsonRResult(statistic=0.06777447420970037, pvalue=0.029950069922659125)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Есть магистральные дороги 100м
# p_value: PearsonRResult(statistic=0.22920748064890775, pvalue=1.0696099445179223e-13)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Есть АЗС 100м
# p_value: PearsonRResult(statistic=0.0908546259554422, pvalue=0.003583599291256247)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Есть скверы 500м
# p_value: PearsonRResult(statistic=-0.10348381985605723, pvalue=0.0009014980496758707)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Есть лес 500м
# p_value: PearsonRResult(statistic=-0.3509681781793768, pvalue=4.158550800931213e-31)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Есть водоем 500м
# p_value: PearsonRResult(statistic=0.20655420332287083, pvalue=2.384741248009752e-11)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Есть пляж 1000м
# p_value: PearsonRResult(statistic=0.2461998287732794, pvalue=1.2449541594489245e-15)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Есть кладбище 250м
# p_value: PearsonRResult(statistic=nan, pvalue=nan)
# Корреляция НЕ является статистически значимой
# Корреляция и p_value: Есть тюрьма 250м
# p_value: PearsonRResult(statistic=0.04087323836720002, pvalue=0.19081530906279776)
# Корреляция НЕ является статистически значимой
# Корреляция и p_value: Есть ПНД 250м
# p_value: PearsonRResult(statistic=0.06020443355175595, pvalue=0.05387746208274096)
# Корреляция НЕ является статистически значимой
# Корреляция и p_value: Есть наркодиспансер 250м
# p_value: PearsonRResult(statistic=nan, pvalue=nan)
# Корреляция НЕ является статистически значимой
# Корреляция и p_value: Есть промзона 250м
# p_value: PearsonRResult(statistic=0.4120845690520806, pvalue=2.497711964308589e-43)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Есть гаражи 500м
# p_value: PearsonRResult(statistic=0.2204814125120576, pvalue=9.21517499330137e-13)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Разнообразие общественного транспорта 1000м
# p_value: PearsonRResult(statistic=0.0634661397198452, pvalue=0.04210610279784203)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Станции электропоезда 1000м
# p_value: PearsonRResult(statistic=0.22440492680927934, pvalue=3.5381991395576836e-13)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Уехать без пересадок: Луговая
# p_value: PearsonRResult(statistic=0.25775876813139315, pvalue=4.9276228746343966e-17)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Расстояние по навигатору до: Луговая
# p_value: PearsonRResult(statistic=-0.23405538128071673, pvalue=3.109850757269338e-14)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Уехать без пересадок: Центр
# p_value: PearsonRResult(statistic=0.0467990583461709, pvalue=0.13412672638313589)
# Корреляция НЕ является статистически значимой
# Корреляция и p_value: Расстояние по навигатору до: Центр
# p_value: PearsonRResult(statistic=-0.3000259159513942, pvalue=8.724483009353492e-23)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Уехать без пересадок: Первая речка
# p_value: PearsonRResult(statistic=0.11308039653981122, pvalue=0.0002841510618036412)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Расстояние по навигатору до: Первая речка
# p_value: PearsonRResult(statistic=-0.25491402764782906, pvalue=1.1077049382545316e-16)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Уехать без пересадок: Вторая речка
# p_value: PearsonRResult(statistic=-0.02653566119726715, pvalue=0.3958348947879983)
# Корреляция НЕ является статистически значимой
# Корреляция и p_value: Расстояние по навигатору до: Вторая речка
# p_value: PearsonRResult(statistic=-0.05539018736517206, pvalue=0.07615998441205518)
# Корреляция НЕ является статистически значимой
# Корреляция и p_value: Уехать без пересадок: Третья рабочая
# p_value: PearsonRResult(statistic=0.08043496263871626, pvalue=0.009952720250797301)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Расстояние по навигатору до: Третья рабочая
# p_value: PearsonRResult(statistic=-0.25359926292411555, pvalue=1.6052582925522807e-16)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Уехать без пересадок: Окатовая
# p_value: PearsonRResult(statistic=0.3747081853363629, pvalue=1.5086452861475928e-35)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Расстояние по навигатору до: Окатовая
# p_value: PearsonRResult(statistic=-0.30004571392327994, pvalue=8.665799506075405e-23)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Уехать без пересадок: Баляева
# p_value: PearsonRResult(statistic=0.04681457992939917, pvalue=0.1339975517876372)
# Корреляция НЕ является статистически значимой
# Корреляция и p_value: Расстояние по навигатору до: Баляева
# p_value: PearsonRResult(statistic=-0.19703834844050036, pvalue=1.9377103110869913e-10)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Уехать без пересадок: Кампус ДВФУ
# p_value: PearsonRResult(statistic=0.4073056338682735, pvalue=2.8112806686548485e-42)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Расстояние по навигатору до: Кампус ДВФУ
# p_value: PearsonRResult(statistic=-0.30708079798681964, pvalue=7.617152396591047e-24)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Расстояние по навигатору до: Артем
# p_value: PearsonRResult(statistic=0.2698061561220084, pvalue=1.4266029874485937e-18)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Расстояние по навигатору до: В-надеждинское
# p_value: PearsonRResult(statistic=0.3143507406815438, pvalue=5.752987867743499e-25)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Есть квартиры без отделки
# p_value: PearsonRResult(statistic=-0.11719485073573951, pvalue=0.0001683637436380271)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Есть квартиры с черновой отделкой
# p_value: PearsonRResult(statistic=0.08521517282279567, pvalue=0.0063106263742213385)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Есть квартиры с чистовой отделкой
# p_value: PearsonRResult(statistic=0.16057708251591526, pvalue=2.330920685021998e-07)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Есть квартиры под ключ
# p_value: PearsonRResult(statistic=0.28068414550105747, pvalue=4.9753422412439995e-20)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Закрытая территория
# p_value: PearsonRResult(statistic=0.13727649785606258, pvalue=1.0209800250766349e-05)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Видеонаблюдение во дворе
# p_value: PearsonRResult(statistic=0.1980830311621976, pvalue=1.547329929343491e-10)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Есть площадки для собак
# p_value: PearsonRResult(statistic=0.07524012985300148, pvalue=0.015930065683761045)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Есть велопарковка
# p_value: PearsonRResult(statistic=0.21607317654582986, pvalue=2.6440643704263464e-12)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Внутренний двор без машин
# p_value: PearsonRResult(statistic=0.30043960553657634, pvalue=7.576107887184648e-23)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Район_Cнеговая падь
# p_value: PearsonRResult(statistic=-0.13025379387116648, pvalue=2.852357681407467e-05)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Район_Артем
# p_value: PearsonRResult(statistic=-0.11373066254704385, pvalue=0.00026189077223278236)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Район_БАМ
# p_value: PearsonRResult(statistic=0.06982068814621087, pvalue=0.025322547894919833)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Район_Баляева
# p_value: PearsonRResult(statistic=-0.02631025641099872, pvalue=0.39986161204609444)
# Корреляция НЕ является статистически значимой
# Корреляция и p_value: Район_Ближний пригород
# p_value: PearsonRResult(statistic=0.017005901108356397, pvalue=0.5863758685515701)
# Корреляция НЕ является статистически значимой
# Корреляция и p_value: Район_Вторая речка
# p_value: PearsonRResult(statistic=-0.04178933541552685, pvalue=0.18105407334301585)
# Корреляция НЕ является статистически значимой
# Корреляция и p_value: Район_Дальний пригород
# p_value: PearsonRResult(statistic=-0.1461493724864062, pvalue=2.5901619103179333e-06)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Район_Заря
# p_value: PearsonRResult(statistic=-0.24542574507819911, pvalue=1.536535293071254e-15)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Район_Змеинка
# p_value: PearsonRResult(statistic=0.007706935862791187, pvalue=0.8052445798977637)
# Корреляция НЕ является статистически значимой
# Корреляция и p_value: Район_Луговая
# p_value: PearsonRResult(statistic=0.05838051171356894, pvalue=0.061579024974985734)
# Корреляция НЕ является статистически значимой
# Корреляция и p_value: Район_Нейбута
# p_value: PearsonRResult(statistic=-0.14082250085724288, pvalue=5.9600743526744805e-06)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Район_Патрокл
# p_value: PearsonRResult(statistic=0.145788497314992, pvalue=2.743186571372393e-06)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Район_Первая речка
# p_value: PearsonRResult(statistic=0.10031036036851124, pvalue=0.0012941870215263727)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Район_Снеговая падь
# p_value: PearsonRResult(statistic=-0.11856179496973138, pvalue=0.00014095613111739995)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Район_Тихая
# p_value: PearsonRResult(statistic=0.017860121560015, pvalue=0.5677082306105699)
# Корреляция НЕ является статистически значимой
# Корреляция и p_value: Район_Третья рабочая
# p_value: PearsonRResult(statistic=0.17045929091420883, pvalue=3.937801105310987e-08)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Район_Центр
# p_value: PearsonRResult(statistic=0.3111519697582349, pvalue=1.8088068893378438e-24)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Район_Чуркин
# p_value: PearsonRResult(statistic=0.366241295971508, pvalue=6.387260173918083e-34)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Основной материал фасада_Другой
# p_value: PearsonRResult(statistic=-0.2714212779340988, pvalue=8.750690507269014e-19)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Основной материал фасада_Камень
# p_value: PearsonRResult(statistic=-0.1044390882863516, pvalue=0.0008069461336669297)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Основной материал фасада_Керамогранит
# p_value: PearsonRResult(statistic=0.12049806166940114, pvalue=0.00010923675031171044)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Основной материал фасада_Кирпич
# p_value: PearsonRResult(statistic=0.08458068531179522, pvalue=0.006712516104985159)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Основной материал фасада_Металл
# p_value: PearsonRResult(statistic=0.14665978405337332, pvalue=2.3876297946744213e-06)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Основной материал фасада_Пластик
# p_value: PearsonRResult(statistic=0.16205020467566317, pvalue=1.8001619174109133e-07)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Основной материал фасада_Стекло
# p_value: PearsonRResult(statistic=0.042879879299427076, pvalue=0.1699226329551782)
# Корреляция НЕ является статистически значимой
# Корреляция и p_value: Вспомогательный материал фасада_Дерево
# p_value: PearsonRResult(statistic=-0.05755429934382615, pvalue=0.06535592769412525)
# Корреляция НЕ является статистически значимой
# Корреляция и p_value: Вспомогательный материал фасада_Другой
# p_value: PearsonRResult(statistic=-0.17676849395385608, pvalue=1.1969804110984394e-08)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Вспомогательный материал фасада_Керамогранит
# p_value: PearsonRResult(statistic=0.05049210999971124, pvalue=0.10601127798771934)
# Корреляция НЕ является статистически значимой
# Корреляция и p_value: Вспомогательный материал фасада_Кирпич
# p_value: PearsonRResult(statistic=-0.03639705718161505, pvalue=0.24409693788401976)
# Корреляция НЕ является статистически значимой
# Корреляция и p_value: Вспомогательный материал фасада_Металл
# p_value: PearsonRResult(statistic=0.23908679786635406, pvalue=8.376710282526973e-15)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Вспомогательный материал фасада_Нет
# p_value: PearsonRResult(statistic=-0.05189067284400822, pvalue=0.09667018974882281)
# Корреляция НЕ является статистически значимой
# Корреляция и p_value: Вспомогательный материал фасада_Пластик
# p_value: PearsonRResult(statistic=0.019714330160056928, pvalue=0.5281936256008625)
# Корреляция НЕ является статистически значимой
# Корреляция и p_value: Вспомогательный материал фасада_Стекло
# p_value: PearsonRResult(statistic=0.07801993904100134, pvalue=0.0124249450380688)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Тип дома_Другой
# p_value: PearsonRResult(statistic=-0.00900508799311614, pvalue=0.7732714836841148)
# Корреляция НЕ является статистически значимой
# Корреляция и p_value: Тип дома_Монолит
# p_value: PearsonRResult(statistic=0.1459578944546178, pvalue=2.670307065684476e-06)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Тип дома_Монолитный каркас
# p_value: PearsonRResult(statistic=0.04871096368859597, pvalue=0.11892633698398637)
# Корреляция НЕ является статистически значимой
# Корреляция и p_value: Тип дома_Панель
# p_value: PearsonRResult(statistic=-0.3189821692619351, pvalue=1.0683916378194702e-25)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Тип фасада_Другой
# p_value: PearsonRResult(statistic=-0.16853833281269437, pvalue=5.6100894493639545e-08)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Тип фасада_Кирпич
# p_value: PearsonRResult(statistic=-0.033536458400430964, pvalue=0.2831784398983605)
# Корреляция НЕ является статистически значимой
# Корреляция и p_value: Тип фасада_Навесной фасад
# p_value: PearsonRResult(statistic=0.3125278609821212, pvalue=1.1070042609590841e-24)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Тип фасада_Панель
# p_value: PearsonRResult(statistic=-0.14802201402447154, pvalue=1.918715451835341e-06)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# Корреляция и p_value: Тип фасада_Стекло
# p_value: PearsonRResult(statistic=0.1448354916447432, pvalue=3.190070242753577e-06)
# Корреляция ЯВЛЯЕТСЯ статистически значимой
# /tmp/ipykernel_5654/796616402.py:30: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   p_value = pearsonr(result['Таргет'], result[atr])

# %%
important.sort(reverse=True, key=lambda x: x[1])
important
np.save('important.npy', important)

# %%
unimportant.sort(reverse=True, key=lambda x: x[1])
unimportant
# Out:
# [['Всего парковочных мест', 0.047485400403915454],
#  ['Есть кладбище 250м', nan],
#  ['Есть ПНД 250м', 0.06020443355175595],
#  ['Есть наркодиспансер 250м', nan],
#  ['Район_Луговая', 0.05838051171356894],
#  ['Вспомогательный материал фасада_Керамогранит', 0.05049210999971124],
#  ['Тип дома_Монолитный каркас', 0.04871096368859597],
#  ['Уехать без пересадок: Баляева', 0.04681457992939917],
#  ['Уехать без пересадок: Центр', 0.0467990583461709],
#  ['Продано нежилых, шт', 0.04542514745557828],
#  ['Основной материал фасада_Стекло', 0.042879879299427076],
#  ['Есть тюрьма 250м', 0.04087323836720002],
#  ['Количество домов 250м', 0.031630231893641544],
#  ['Вспомогательный материал фасада_Пластик', 0.019714330160056928],
#  ['Район_Тихая', 0.017860121560015],
#  ['Район_Ближний пригород', 0.017005901108356397],
#  ['Продано квартир, руб', 0.01392906929086924],
#  ['Инфраструктура: Супермаркеты', 0.01364007563273089],
#  ['Район_Змеинка', 0.007706935862791187],
#  ['Тип дома_Другой', -0.00900508799311614],
#  ['Инфраструктура: Торговые центры', -0.01902998055396974],
#  ['Район_Баляева', -0.02631025641099872],
#  ['Уехать без пересадок: Вторая речка', -0.02653566119726715],
#  ['Парковочных мест у дома', -0.028646460075476388],
#  ['Тип фасада_Кирпич', -0.033536458400430964],
#  ['Вспомогательный материал фасада_Кирпич', -0.03639705718161505],
#  ['Район_Вторая речка', -0.04178933541552685],
#  ['Количество студий', -0.04466247868034856],
#  ['Вспомогательный материал фасада_Нет', -0.05189067284400822],
#  ['Статус', -0.05285235952173934],
#  ['Расстояние по навигатору до: Вторая речка', -0.05539018736517206],
#  ['Вспомогательный материал фасада_Дерево', -0.05755429934382615],
#  ['Количество квартир на этаже', -0.05764213087071952]]
